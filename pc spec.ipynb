# %%
import platform

# %%
platform.machine()
# Out:
# 'x86_64'

# %%
platform.version()
# Out:
# '#206-Ubuntu SMP Fri Feb 28 05:02:04 UTC 2020'

# %%
platform.platform()
# Out:
# 'Linux-4.4.0-176-generic-x86_64-with-debian-stretch-sid'

# %%
platform.uname()
# Out:
# uname_result(system='Linux', node='nipa2020-0771', release='4.4.0-176-generic', version='#206-Ubuntu SMP Fri Feb 28 05:02:04 UTC 2020', machine='x86_64', processor='x86_64')

# %%
platform.system()
# Out:
# 'Linux'

# %%
platform.processor()
# Out:
# 'x86_64'

# %%
import psutil

# %%
round(psutil.virtual_memory().total / (1024.0 **3))  # GB
# Out:
# 177

# %%
round(psutil.disk_usage('/').total / (1024.0 **3))  # GB
# Out:
# 47

# %%
# !pip install gpustat
# Out:
# Looking in indexes: http://ftp.daumkakao.com/pypi/simple
# ...
#      |################################| 78 kB 18.9 MB/s eta 0:00:01
# ...
# Processing /home/ubuntu/.cache/pip/wheels/d3/16/06/a5b34f4ae91b3107a46efddfef4b0a36d19db5d0ca50925d6a/nvidia_ml_py3-7.352.0-cp36-none-any.whl
# ...
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=45231ac0d3ea483218666922161bd2bc33e425fc39130d974a54144a0ac3ffa8
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/0f/79/fa/ff30712259d0a84748ce0f41a4e7b716016159b25c8f4f5318
# Successfully built gpustat
# ...

# %%
import gpustat

# %%
gpustat.print_gpustat()
# Out:
# nipa2020-0771            Thu May 14 16:54:39 2020  418.67
# [0] Tesla V100-SXM2-32GB | 36'C,   0 % |  1015 / 32480 MB | ubuntu(1005M)
# [1] Tesla V100-SXM2-32GB | 30'C,   0 % |    10 / 32480 MB |

# %%
gpustat.print_gpustat(1)
# Out:
# {
#     "hostname": "nipa2020-0771",
#     "query_time": "2020-05-14T17:32:25.169301",
#     "gpus": [
#         {
#             "index": 0,
#             "uuid": "GPU-1d62ec9e-b78e-4495-1104-c67fb5135bbd",
#             "name": "Tesla V100-SXM2-32GB",
#             "temperature.gpu": 35,
#             "fan.speed": null,
#             "utilization.gpu": 0,
#             "power.draw": 63,
#             "enforced.power.limit": 300,
#             "memory.used": 1015,
#             "memory.total": 32480,
#             "processes": [
#                 {
#                     "username": "ubuntu",
#                     "command": "python",
#                     "gpu_memory_usage": 1005,
#                     "pid": 12671
#                 }
#             ]
#         },
#         {
#             "index": 1,
#             "uuid": "GPU-37bab754-32ff-7764-4510-0929199f05da",
#             "name": "Tesla V100-SXM2-32GB",
#             "temperature.gpu": 30,
#             "fan.speed": null,
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 16.04.1 LTS
# Release:	16.04
# Codename:	xenial

# %%
# !nvidia-smi
# Out:
# Thu May 14 17:45:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:05.0 Off |                  Off |
# | N/A   35C    P0    63W / 300W |   1015MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:00:06.0 Off |                  Off |
# | N/A   30C    P0    37W / 300W |     10MiB / 32480MiB |      0%      Default |
# ...

# %%
# !cat /usr/local/cuda/include/cudnn.h
# Out:
# /*
#  * Copyright 1993-2015 NVIDIA Corporation.  All rights reserved.
#  *
#  * NOTICE TO LICENSEE:
#  *
#  * This source code and/or documentation ("Licensed Deliverables") are
#  * subject to NVIDIA intellectual property rights under U.S. and
#  * international Copyright laws.
#  *
#  * These Licensed Deliverables contained herein is PROPRIETARY and
#  * CONFIDENTIAL to NVIDIA and is being provided under the terms and
#  * conditions of a form of NVIDIA software license agreement by and
#  * between NVIDIA and Licensee ("License Agreement") or electronically
#  * accepted by Licensee.  Notwithstanding any terms or conditions to
#  * the contrary in the License Agreement, reproduction or disclosure
#  * of the Licensed Deliverables to any third party without the express
#  * written consent of NVIDIA is prohibited.
#  *
#  * NOTWITHSTANDING ANY TERMS OR CONDITIONS TO THE CONTRARY IN THE
#  * LICENSE AGREEMENT, NVIDIA MAKES NO REPRESENTATION ABOUT THE
# ...
